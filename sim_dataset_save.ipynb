# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from skimage.transform import iradon, radon

from racts_utils import save_files, get_path_dict, load_sim_data, raw2sino

# %% [markdown]
# # Save files

# %%
from importlib import reload
import utils
reload(utils)
from utils import save_files

# options
settings = dict(
            dobj_value=5.16,
            radius=20,
            spread=10,
            n_samples=512,
            circle=False
            )

for dset in ['train', 'val', 'test']:
    version = 1
    save_files(dset, version=0, max_n=1e5, test_run=True, **settings)

# %%
dir()
# Out:
# ['In',
#  'Out',
#  'Path',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'dset',
#  'exit',
#  'get_ipython',
#  'get_path_dict',
#  'h5py',
#  'iradon',
#  'load_sim_data',
#  'np',
#  'open',
#  'os',
#  'plt',
#  'quit',
#  'radon',
#  'raw2sino',
#  'save_files',
#  'settings',
#  'version']

# %% [markdown]
# # Load in data

# %%
img, sino, settings = load_sim_data(0, dset='train', version=0)
plt.imshow(img)

# %% [markdown]
# # Useful code

# %%
# # check total number of images
# ct_dct =  get_path_dict()
# n_tot = 0
# for dset in ['train', 'val', 'test']:
#     for mode in ['ground_truth', 'observation']:
#         paths = ct_dct[dset][mode]
#         for p in paths:
#             f = h5py.File(p, 'r')
#             n_tot += f['data'].shape[0]
# n_tot

# %%
### FOR TESTING IF CODE IS WORKING
# img = # NEED TO DEFINE

# # options
# dobj_value=5.16
# radius=20
# spread=10
# n_samples=362
# circle=False
# 
#  dobj_img, sino, sample_radius = raw2sino(img, dobj=True, 
#                                       dobj_value=dobj_value, 
#                                       radius=radius, 
#                                       spread=spread, 
#                                       n_samples=n_samples, 
#                                       circle=circle)
